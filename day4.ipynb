# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread('/home/murali/Downloads/2_62306456bfd96.jpg')
plt.imshow(image)

# %%
img = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
plt.imshow(img)

# %%
img = cv2.cvtColor(image, cv2.COLOR_BGR2HLS)
plt.imshow(img)

# %%
image1=cv2.imread("/home/murali/Downloads/dogs-in-bags-instagram-618d2a61db3c5__700.jpg")
image1=cv2.cvtColor(image1,cv2.COLOR_BGR2RGB)

image2=cv2.imread("/home/murali/Downloads/do-not-copy-160137_1280.png")
image2=cv2.cvtColor(image2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image1)

# %%
plt.imshow(image2)

# %%
image2=cv2.resize(image2,(600,600))
image1=cv2.resize(image1,(600,600))

# %%
blend = cv2.addWeighted(src1=image1,alpha=0.5,src2=image2,beta=0.3,gamma=0.0)
plt.imshow(blend)

# %%
image1=cv2.imread("/home/murali/Downloads/dogs-in-bags-instagram-618d2a61db3c5__700.jpg")
image1=cv2.cvtColor(image1,cv2.COLOR_BGR2RGB)

image2=cv2.imread("/home/murali/Downloads/do-not-copy-160137_1280.png")
image2=cv2.cvtColor(image2,cv2.COLOR_BGR2RGB)

# %%
image2 = cv2.resize(image2,(600,600))

# %%
x_offset , y_offset = 0,0
x_end = (x_offset + image2.shape[0])
y_end = (y_offset + image2.shape[1])

# %%
image1[y_offset:y_end,x_offset:x_end] = image2

# %%
plt.imshow(image1)
