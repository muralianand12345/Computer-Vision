# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("some/wrong/path/some.png")
# Out:
# [ WARN:0@3113.417] global loadsave.cpp:248 findDecoder imread_('some/wrong/path/some.png'): can't open/read file: check file path/integrity

# %%
print(img)
# Out:
# None

# %%
img = cv2.imread('/home/murali/Downloads/71955467.jpeg')

# %%
img
# Out:
# array([[[16, 23, 62],
#         [15, 22, 61],
#         [14, 21, 60],
#         ...,
#         [ 0,  2,  2],
#         [ 0,  2,  2],
#         [ 0,  2,  2]],
#
#        [[14, 20, 61],
#         [14, 21, 60],
#         [14, 20, 61],
#         ...,
#         [ 1,  3,  3],
#         [ 1,  3,  3],
#         [ 1,  3,  3]],
#
#        [[16, 19, 63],
#         [17, 21, 62],
#         [17, 20, 64],
#         ...,
#         [ 2,  4,  4],
#         [ 2,  4,  4],
#         [ 2,  4,  4]],
#
#        ...,
#
#        [[41, 50, 63],
#         [42, 51, 64],
#         [43, 52, 65],
#         ...,
#         [ 9, 12, 26],
#         [11, 13, 31],
#         [11, 15, 34]],
#
#        [[39, 48, 61],
#         [40, 49, 62],
#         [41, 50, 63],
#         ...,
#         [ 8, 11, 25],
#         [10, 12, 30],
#         [10, 14, 33]],
#
#        [[38, 47, 60],
#         [38, 47, 60],
#         [39, 48, 61],
#         ...,
#         [ 7, 10, 24],
#         [ 9, 11, 29],
#         [ 9, 13, 32]]], dtype=uint8)

# %%
img.shape
# Out:
# (460, 460, 3)

# %%
plt.imshow(img)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
img_gray = cv2.imread("/home/murali/Downloads/2_62306456bfd96.jpg", cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap="gray")

# %%
img_rgb.shape
# Out:
# (460, 460, 3)

# %%
img_gray.shape
# Out:
# (900, 747)

# %%
img = cv2.resize(img_rgb, (1000, 1000))
plt.imshow(img)

# %%
w_ratio = 0.5
h_ratio = 0.5

new_img = cv2.resize(img_rgb, (0,0), img_rgb, w_ratio, h_ratio) #init image height and width

#new_width = original_width * w_ratio
#new_height = original_height * h_ratio

plt.imshow(new_img)

# %%
img_rgb.shape
# Out:
# (460, 460, 3)

# %%
new_img.shape
# Out:
# (230, 230, 3)

# %%
new_img = cv2.flip(new_img,0)
plt.imshow(new_img)

# %%
new_img = cv2.flip(new_img,1)
plt.imshow(new_img)

# %%
new_img = cv2.flip(new_img,-1)
plt.imshow(new_img)

# %%
new_img = cv2.flip(new_img,5)
plt.imshow(new_img)

# %%
type(new_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('newpicture.jpg', new_img)
# Out:
# True

# %%
#from google.colab.patches import cv2_imshow

# %%
img_nearest = cv2.resize(img, (10000,10000), interpolation=cv2.INTER_NEAREST)

# %%
img_bilinear = cv2.resize(img, (10000,10000), interpolation=cv2.INTER_LINEAR)

# %%
img_bicubic = cv2.resize(img, (10000,10000), interpolation=cv2.INTER_CUBIC)

# %%
img_lancozos = cv2.resize(img, (10000,10000), interpolation=cv2.INTER_LANCZOS4)

# %%
plt.imshow(img)

# %%
plt.imshow(img_nearest)

# %%
plt.imshow(img_bicubic)

# %%
plt.imshow(img_bilinear)

# %%
plt.imshow(img_lancozos)

# %%
cv2.imwrite('newpicture.jpg', img)
cv2.imwrite('newpicture1.jpg', img_lancozos)
# Out:
# True
